# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
print(sns.get_dataset_names())
# Out:
# C:\Users\varsharavi\anaconda3\lib\site-packages\seaborn\utils.py:384: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 384 of the file C:\Users\varsharavi\anaconda3\lib\site-packages\seaborn\utils.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   gh_list = BeautifulSoup(http)
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'geyser', 'iris', 'mpg', 'penguins', 'planets', 'taxis', 'tips', 'titanic']

# %%
titanic=sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df=pd.read_csv(r'test.csv')

# %%
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 0      male  34.5      0      0              330911    7.8292   NaN        Q
# 1    female  47.0      1      0              363272    7.0000   NaN        S
# 2      male  62.0      0      0              240276    9.6875   NaN        Q
# 3      male  27.0      0      0              315154    8.6625   NaN        S
# 4    female  22.0      1      1             3101298   12.2875   NaN        S
# ..      ...   ...    ...    ...                 ...       ...   ...      ...
# 413    male   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  female  39.0      0      0            PC 17758  108.9000  C105        C
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416    male   NaN      0      0              359309    8.0500   NaN        S
# 417    male   NaN      1      1                2668   22.3583   NaN        C
#
# [418 rows x 11 columns]

# %%
df.shape
# Out:
# (418, 11)

# %%
df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Pclass                          Name     Sex   Age  SibSp  \
# 413         1305       3            Spector, Mr. Woolf    male   NaN      0
# 414         1306       1  Oliva y Ocana, Dona. Fermina  female  39.0      0
# 415         1307       3  Saether, Mr. Simon Sivertsen    male  38.5      0
# 416         1308       3           Ware, Mr. Frederick    male   NaN      0
# 417         1309       3      Peter, Master. Michael J    male   NaN      1
#
#      Parch              Ticket      Fare Cabin Embarked
# 413      0           A.5. 3236    8.0500   NaN        S
# 414      0            PC 17758  108.9000  C105        C
# 415      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416      0              359309    8.0500   NaN        S
# 417      1                2668   22.3583   NaN        C

# %%
df.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df.Age=df.Age.fillna(df.Age.median())

# %%
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 0      male  34.5      0      0              330911    7.8292   NaN        Q
# 1    female  47.0      1      0              363272    7.0000   NaN        S
# 2      male  62.0      0      0              240276    9.6875   NaN        Q
# 3      male  27.0      0      0              315154    8.6625   NaN        S
# 4    female  22.0      1      1             3101298   12.2875   NaN        S
# ..      ...   ...    ...    ...                 ...       ...   ...      ...
# 413    male  27.0      0      0           A.5. 3236    8.0500   NaN        S
# 414  female  39.0      0      0            PC 17758  108.9000  C105        C
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416    male  27.0      0      0              359309    8.0500   NaN        S
# 417    male  27.0      1      1                2668   22.3583   NaN        C
#
# [418 rows x 11 columns]

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 0      male  34.5      0      0              330911    7.8292   NaN        Q
# 1    female  47.0      1      0              363272    7.0000   NaN        S
# 2      male  62.0      0      0              240276    9.6875   NaN        Q
# 3      male  27.0      0      0              315154    8.6625   NaN        S
# 4    female  22.0      1      1             3101298   12.2875   NaN        S
# ..      ...   ...    ...    ...                 ...       ...   ...      ...
# 413    male  27.0      0      0           A.5. 3236    8.0500   NaN        S
# 414  female  39.0      0      0            PC 17758  108.9000  C105        C
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416    male  27.0      0      0              359309    8.0500   NaN        S
# 417    male  27.0      1      1                2668   22.3583   NaN        C
#
# [418 rows x 11 columns]

# %%
df.loc[2:5]
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 5          897       3                    Svensson, Mr. Johan Cervin    male
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S
# 5  14.0      0      0     7538   9.2250   NaN        S

# %%
df.loc[df.Age>40]
# Out:
#      PassengerId  Pclass                                               Name  \
# 1            893       3                   Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                          Myles, Mr. Thomas Francis
# 11           903       1                         Jones, Mr. Charles Cresson
# 13           905       2                               Howard, Mr. Benjamin
# 14           906       1  Chaffee, Mrs. Herbert Fuller (Carrie Constance...
# ..           ...     ...                                                ...
# 391         1283       1     Lines, Mrs. Ernest H (Elizabeth Lindsey James)
# 393         1285       2                               Gilbert, Mr. William
# 397         1289       1  Frolicher-Stehli, Mrs. Maxmillian (Margaretha ...
# 404         1296       1                       Frauenthal, Mr. Isaac Gerald
# 407         1299       1                         Widener, Mr. George Dunton
#
#         Sex   Age  SibSp  Parch       Ticket      Fare Cabin Embarked
# 1    female  47.0      1      0       363272    7.0000   NaN        S
# 2      male  62.0      0      0       240276    9.6875   NaN        Q
# 11     male  46.0      0      0          694   26.0000   NaN        S
# 13     male  63.0      1      0        24065   26.0000   NaN        S
# 14   female  47.0      1      0  W.E.P. 5734   61.1750   E31        S
# ..      ...   ...    ...    ...          ...       ...   ...      ...
# 391  female  51.0      0      1     PC 17592   39.4000   D28        S
# 393    male  47.0      0      0   C.A. 30769   10.5000   NaN        S
# 397  female  48.0      1      1        13567   79.2000   B41        C
# 404    male  43.0      1      0        17765   27.7208   D40        C
# 407    male  50.0      1      1       113503  211.5000   C80        C
#
# [77 rows x 11 columns]

# %%
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 0      male  34.5      0      0              330911    7.8292   NaN        Q
# 1    female  47.0      1      0              363272    7.0000   NaN        S
# 2      male  62.0      0      0              240276    9.6875   NaN        Q
# 3      male  27.0      0      0              315154    8.6625   NaN        S
# 4    female  22.0      1      1             3101298   12.2875   NaN        S
# ..      ...   ...    ...    ...                 ...       ...   ...      ...
# 413    male  27.0      0      0           A.5. 3236    8.0500   NaN        S
# 414  female  39.0      0      0            PC 17758  108.9000  C105        C
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416    male  27.0      0      0              359309    8.0500   NaN        S
# 417    male  27.0      1      1                2668   22.3583   NaN        C
#
# [418 rows x 11 columns]

# %%
df.shape
# Out:
# (418, 11)

# %%
df.iloc[:,:]
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 0      male  34.5      0      0              330911    7.8292   NaN        Q
# 1    female  47.0      1      0              363272    7.0000   NaN        S
# 2      male  62.0      0      0              240276    9.6875   NaN        Q
# 3      male  27.0      0      0              315154    8.6625   NaN        S
# 4    female  22.0      1      1             3101298   12.2875   NaN        S
# ..      ...   ...    ...    ...                 ...       ...   ...      ...
# 413    male  27.0      0      0           A.5. 3236    8.0500   NaN        S
# 414  female  39.0      0      0            PC 17758  108.9000  C105        C
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416    male  27.0      0      0              359309    8.0500   NaN        S
# 417    male  27.0      1      1                2668   22.3583   NaN        C
#
# [418 rows x 11 columns]

# %%
df.iloc[:,[0,2]]
# Out:
#      PassengerId                                          Name
# 0            892                              Kelly, Mr. James
# 1            893              Wilkes, Mrs. James (Ellen Needs)
# 2            894                     Myles, Mr. Thomas Francis
# 3            895                              Wirz, Mr. Albert
# 4            896  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...                                           ...
# 413         1305                            Spector, Mr. Woolf
# 414         1306                  Oliva y Ocana, Dona. Fermina
# 415         1307                  Saether, Mr. Simon Sivertsen
# 416         1308                           Ware, Mr. Frederick
# 417         1309                      Peter, Master. Michael J
#
# [418 rows x 2 columns]

# %%
x=df.iloc[:,-1]

# %%
type(x)
# Out:
# pandas.core.series.Series

# %%
df.iloc[:,range(0,3)]
# Out:
#      PassengerId  Pclass                                          Name
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
# [418 rows x 3 columns]

# %%
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 0      male  34.5      0      0              330911    7.8292   NaN        Q
# 1    female  47.0      1      0              363272    7.0000   NaN        S
# 2      male  62.0      0      0              240276    9.6875   NaN        Q
# 3      male  27.0      0      0              315154    8.6625   NaN        S
# 4    female  22.0      1      1             3101298   12.2875   NaN        S
# ..      ...   ...    ...    ...                 ...       ...   ...      ...
# 413    male  27.0      0      0           A.5. 3236    8.0500   NaN        S
# 414  female  39.0      0      0            PC 17758  108.9000  C105        C
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416    male  27.0      0      0              359309    8.0500   NaN        S
# 417    male  27.0      1      1                2668   22.3583   NaN        C
#
# [418 rows x 11 columns]

# %%
from sklearn.preprocessing import LabelEncoder
from collections import Counter as count
le=LabelEncoder()
print('Before label Encoding: ',count(df['Name']))
df['Name']=le.fit_transform(df['Name'])
print('After label Encoding: ',count(df['Name']))
# Out:
# Before label Encoding:  Counter({'Kelly, Mr. James': 1, 'Wilkes, Mrs. James (Ellen Needs)': 1, 'Myles, Mr. Thomas Francis': 1, 'Wirz, Mr. Albert': 1, 'Hirvonen, Mrs. Alexander (Helga E Lindqvist)': 1, 'Svensson, Mr. Johan Cervin': 1, 'Connolly, Miss. Kate': 1, 'Caldwell, Mr. Albert Francis': 1, 'Abrahim, Mrs. Joseph (Sophie Halaut Easu)': 1, 'Davies, Mr. John Samuel': 1, 'Ilieff, Mr. Ylio': 1, 'Jones, Mr. Charles Cresson': 1, 'Snyder, Mrs. John Pillsbury (Nelle Stevenson)': 1, 'Howard, Mr. Benjamin': 1, 'Chaffee, Mrs. Herbert Fuller (Carrie Constance Toogood)': 1, 'del Carlo, Mrs. Sebastiano (Argenia Genovesi)': 1, 'Keane, Mr. Daniel': 1, 'Assaf, Mr. Gerios': 1, 'Ilmakangas, Miss. Ida Livija': 1, 'Assaf Khalil, Mrs. Mariana (Miriam")"': 1, 'Rothschild, Mr. Martin': 1, 'Olsen, Master. Artur Karl': 1, 'Flegenheim, Mrs. Alfred (Antoinette)': 1, 'Williams, Mr. Richard Norris II': 1, 'Ryerson, Mrs. Arthur Larned (Emily Maria Borie)': 1, 'Robins, Mr. Alexander A': 1, 'Ostby, Miss. Helene Ragnhild': 1, 'Daher, Mr. Shedid': 1, 'Brady, Mr. John Bertram': 1, 'Samaan, Mr. Elias': 1, 'Louch, Mr. Charles Alexander': 1, 'Jefferys, Mr. Clifford Thomas': 1, 'Dean, Mrs. Bertram (Eva Georgetta Light)': 1, 'Johnston, Mrs. Andrew G (Elizabeth Lily" Watson)"': 1, 'Mock, Mr. Philipp Edmund': 1, 'Katavelas, Mr. Vassilios (Catavelas Vassilios")"': 1, 'Roth, Miss. Sarah A': 1, 'Cacic, Miss. Manda': 1, 'Sap, Mr. Julius': 1, 'Hee, Mr. Ling': 1, 'Karun, Mr. Franz': 1, 'Franklin, Mr. Thomas Parham': 1, 'Goldsmith, Mr. Nathan': 1, 'Corbett, Mrs. Walter H (Irene Colvin)': 1, 'Kimball, Mrs. Edwin Nelson Jr (Gertrude Parsons)': 1, 'Peltomaki, Mr. Nikolai Johannes': 1, 'Chevre, Mr. Paul Romaine': 1, 'Shaughnessy, Mr. Patrick': 1, 'Bucknell, Mrs. William Robert (Emma Eliza Ward)': 1, 'Coutts, Mrs. William (Winnie Minnie" Treanor)"': 1, 'Smith, Mr. Lucien Philip': 1, 'Pulbaum, Mr. Franz': 1, 'Hocking, Miss. Ellen Nellie""': 1, 'Fortune, Miss. Ethel Flora': 1, 'Mangiavacchi, Mr. Serafino Emilio': 1, 'Rice, Master. Albert': 1, 'Cor, Mr. Bartol': 1, 'Abelseth, Mr. Olaus Jorgensen': 1, 'Davison, Mr. Thomas Henry': 1, 'Chaudanson, Miss. Victorine': 1, 'Dika, Mr. Mirko': 1, 'McCrae, Mr. Arthur Gordon': 1, 'Bjorklund, Mr. Ernst Herbert': 1, 'Bradley, Miss. Bridget Delia': 1, 'Ryerson, Master. John Borie': 1, 'Corey, Mrs. Percy C (Mary Phyllis Elizabeth Miller)': 1, 'Burns, Miss. Mary Delia': 1, 'Moore, Mr. Clarence Bloomfield': 1, 'Tucker, Mr. Gilbert Milligan Jr': 1, 'Fortune, Mrs. Mark (Mary McDougald)': 1, 'Mulvihill, Miss. Bertha E': 1, 'Minkoff, Mr. Lazar': 1, 'Nieminen, Miss. Manta Josefina': 1, 'Ovies y Rodriguez, Mr. Servando': 1, 'Geiger, Miss. Amalie': 1, 'Keeping, Mr. Edwin': 1, 'Miles, Mr. Frank': 1, 'Cornell, Mrs. Robert Clifford (Malvina Helen Lamson)': 1, 'Aldworth, Mr. Charles Augustus': 1, 'Doyle, Miss. Elizabeth': 1, 'Boulos, Master. Akar': 1, 'Straus, Mr. Isidor': 1, 'Case, Mr. Howard Brown': 1, 'Demetri, Mr. Marinko': 1, 'Lamb, Mr. John Joseph': 1, 'Khalil, Mr. Betros': 1, 'Barry, Miss. Julia': 1, 'Badman, Miss. Emily Louisa': 1, "O'Donoghue, Ms. Bridget": 1, 'Wells, Master. Ralph Lester': 1, 'Dyker, Mrs. Adolf Fredrik (Anna Elisabeth Judith Andersson)': 1, 'Pedersen, Mr. Olaf': 1, 'Davidson, Mrs. Thornton (Orian Hays)': 1, 'Guest, Mr. Robert': 1, 'Birnbaum, Mr. Jakob': 1, 'Tenglin, Mr. Gunnar Isidor': 1, 'Cavendish, Mrs. Tyrell William (Julia Florence Siegel)': 1, 'Makinen, Mr. Kalle Edvard': 1, 'Braf, Miss. Elin Ester Maria': 1, 'Nancarrow, Mr. William Henry': 1, 'Stengel, Mrs. Charles Emil Henry (Annie May Morris)': 1, 'Weisz, Mr. Leopold': 1, 'Foley, Mr. William': 1, 'Johansson Palmquist, Mr. Oskar Leander': 1, 'Thomas, Mrs. Alexander (Thamine Thelma")"': 1, 'Holthen, Mr. Johan Martin': 1, 'Buckley, Mr. Daniel': 1, 'Ryan, Mr. Edward': 1, 'Willer, Mr. Aaron (Abi Weller")"': 1, 'Swane, Mr. George': 1, 'Stanton, Mr. Samuel Ward': 1, 'Shine, Miss. Ellen Natalia': 1, 'Evans, Miss. Edith Corse': 1, 'Buckley, Miss. Katherine': 1, 'Straus, Mrs. Isidor ( ...
# After label Encoding:  Counter({206: 1, 403: 1, 269: 1, 408: 1, 178: 1, 366: 1, 84: 1, 57: 1, 4: 1, 103: 1, 187: 1, 196: 1, 352: 1, 184: 1, 69: 1, 415: 1, 204: 1, 21: 1, 188: 1, 20: 1, 324: 1, 284: 1, 138: 1, 406: 1, 329: 1, 318: 1, 288: 1, 97: 1, 44: 1, 339: 1, 236: 1, 190: 1, 109: 1, 195: 1, 264: 1, 203: 1, 323: 1, 55: 1, 342: 1, 170: 1, 202: 1, 148: 1, 158: 1, 88: 1, 212: 1, 300: 1, 72: 1, 345: 1, 53: 1, 92: 1, 348: 1, 309: 1, 179: 1, 144: 1, 247: 1, 314: 1, 86: 1, 2: 1, 106: 1, 71: 1, 115: 1, 255: 1, 36: 1, 43: 1, 327: 1, 89: 1, 54: 1, 265: 1, 378: 1, 145: 1, 267: 1, 263: 1, 275: 1, 289: 1, 152: 1, 205: 1, 261: 1, 90: 1, 6: 1, 121: 1, 40: 1, 363: 1, 66: 1, 111: 1, 221: 1, 209: 1, 27: 1, 25: 1, 281: 1, 392: 1, 129: 1, 299: 1, 101: 1, 163: 1, 35: 1, 369: 1, 68: 1, 244: 1, 45: 1, 271: 1, 360: 1, 391: 1, 141: 1, 192: 1, 373: 1, 182: 1, 52: 1, 326: 1, 405: 1, 367: 1, 358: 1, 346: 1, 133: 1, 51: 1, 364: 1, 75: 1, 371: 1, 341: 1, 28: 1, 70: 1, 390: 1, 211: 1, 343: 1, 65: 1, 207: 1, 94: 1, 47: 1, 254: 1, 42: 1, 303: 1, 357: 1, 161: 1, 225: 1, 370: 1, 116: 1, 62: 1, 411: 1, 344: 1, 122: 1, 160: 1, 159: 1, 100: 1, 328: 1, 29: 1, 227: 1, 379: 1, 175: 1, 102: 1, 93: 1, 220: 1, 130: 1, 250: 1, 362: 1, 217: 1, 17: 1, 126: 1, 34: 1, 237: 1, 38: 1, 297: 1, 350: 1, 376: 1, 410: 1, 298: 1, 301: 1, 215: 1, 46: 1, 143: 1, 67: 1, 171: 1, 233: 1, 412: 1, 128: 1, 375: 1, 18: 1, 48: 1, 347: 1, 359: 1, 31: 1, 82: 1, 256: 1, 81: 1, 249: 1, 222: 1, 119: 1, 251: 1, 304: 1, 104: 1, 334: 1, 381: 1, 13: 1, 338: 1, 417: 1, 232: 1, 123: 1, 200: 1, 354: 1, 277: 1, 26: 1, 311: 1, 268: 1, 99: 1, 23: 1, 310: 1, 11: 1, 286: 1, 257: 1, 80: 1, 321: 1, 110: 1, 8: 1, 137: 1, 107: 1, 185: 1, 9: 1, 169: 1, 242: 1, 399: 1, 401: 1, 374: 1, 127: 1, 312: 1, 85: 1, 199: 1, 59: 1, 266: 1, 19: 1, 259: 1, 134: 1, 180: 1, 368: 1, 404: 1, 402: 1, 230: 1, 96: 1, 382: 1, 389: 1, 24: 1, 176: 1, 120: 1, 229: 1, 74: 1, 355: 1, 186: 1, 194: 1, 208: 1, 201: 1, 124: 1, 181: 1, 210: 1, 395: 1, 3: 1, 76: 1, 337: 1, 394: 1, 240: 1, 243: 1, 276: 1, 32: 1, 260: 1, 414: 1, 278: 1, 393: 1, 216: 1, 308: 1, 239: 1, 73: 1, 388: 1, 183: 1, 306: 1, 252: 1, 146: 1, 77: 1, 226: 1, 330: 1, 50: 1, 293: 1, 135: 1, 385: 1, 290: 1, 287: 1, 295: 1, 139: 1, 377: 1, 320: 1, 113: 1, 147: 1, 351: 1, 248: 1, 142: 1, 313: 1, 98: 1, 272: 1, 117: 1, 409: 1, 12: 1, 223: 1, 340: 1, 235: 1, 193: 1, 285: 1, 245: 1, 305: 1, 307: 1, 253: 1, 95: 1, 7: 1, 5: 1, 168: 1, 165: 1, 56: 1, 380: 1, 331: 1, 63: 1, 398: 1, 164: 1, 356: 1, 319: 1, 197: 1, 191: 1, 10: 1, 218: 1, 274: 1, 325: 1, 219: 1, 22: 1, 30: 1, 322: 1, 78: 1, 132: 1, 105: 1, 125: 1, 372: 1, 270: 1, 87: 1, 241: 1, 413: 1, 131: 1, 112: 1, 33: 1, 136: 1, 238: 1, 335: 1, 61: 1, 416: 1, 1: 1, 39: 1, 396: 1, 157: 1, 383: 1, 162: 1, 361: 1, 114: 1, 174: 1, 108: 1, 198: 1, 49: 1, 234: 1, 282: 1, 228: 1, 333: 1, 246: 1, 387: 1, 365: 1, 167: 1, 336: 1, 60: 1, 315: 1, 154: 1, 291: 1, 156: 1, 407: 1, 189: 1, 166: 1, 118: 1, 41: 1, 213: 1, 91: 1, 177: 1, 16: 1, 280: 1, 140: 1, 317: 1, 258: 1, 397: 1, 173: 1, 14: 1, 15: 1, 58: 1, 292: 1, 294: 1, 231: 1, 0: 1, 155: 1, 214: 1, 349: 1, 79: 1, 150: 1, 224: 1, 83: 1, 37: 1, 151: 1, 153: 1, 64: 1, 149: 1, 279: 1, 386: 1, 400: 1, 316: 1, 296: 1, 273: 1, 262: 1, 172: 1, 353: 1, 283: 1, 332: 1, 384: 1, 302: 1})

# %%
from sklearn.compose import ColumnTransformer 
from sklearn.preprocessing import OneHotEncoder
ct=ColumnTransformer([('on',OneHotEncoder(),[3])],remainder='passthrough')
df=ct.fit_transform(df)

# %%
df
# Out:
# array([[0.0, 1.0, 892, ..., 7.8292, nan, 'Q'],
#        [1.0, 0.0, 893, ..., 7.0, nan, 'S'],
#        [0.0, 1.0, 894, ..., 9.6875, nan, 'Q'],
#        ...,
#        [0.0, 1.0, 1307, ..., 7.25, nan, 'S'],
#        [0.0, 1.0, 1308, ..., 8.05, nan, 'S'],
#        [0.0, 1.0, 1309, ..., 22.3583, nan, 'C']], dtype=object)

# %%
x=pd.DataFrame(df[:,0:5],columns=['France','Germany','Spain','Age','Salary'])
x
# Out:
#     France Germany Spain Age Salary
# 0        0       1   892   3    206
# 1        1       0   893   3    403
# 2        0       1   894   2    269
# 3        0       1   895   3    408
# 4        1       0   896   3    178
# ..     ...     ...   ...  ..    ...
# 413      0       1  1305   3    353
# 414      1       0  1306   1    283
# 415      0       1  1307   3    332
# 416      0       1  1308   3    384
# 417      0       1  1309   3    302
#
# [418 rows x 5 columns]

# %%
y=pd.DataFrame(df[:,3],columns=['Age'])
y
# Out:
#     Age
# 0     3
# 1     3
# 2     2
# 3     3
# 4     3
# ..   ..
# 413   3
# 414   1
# 415   3
# 416   3
# 417   3
#
# [418 rows x 1 columns]

# %%
df
# Out:
# array([[0.0, 1.0, 892, ..., 7.8292, nan, 'Q'],
#        [1.0, 0.0, 893, ..., 7.0, nan, 'S'],
#        [0.0, 1.0, 894, ..., 9.6875, nan, 'Q'],
#        ...,
#        [0.0, 1.0, 1307, ..., 7.25, nan, 'S'],
#        [0.0, 1.0, 1308, ..., 8.05, nan, 'S'],
#        [0.0, 1.0, 1309, ..., 22.3583, nan, 'C']], dtype=object)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train
# Out:
#     France Germany Spain Age Salary
# 20       0       1   912   1    324
# 306      0       1  1198   1      7
# 142      0       1  1034   1    328
# 14       1       0   906   1     69
# 284      1       0  1176   3    320
# ..     ...     ...   ...  ..    ...
# 323      0       1  1215   1    325
# 192      0       1  1084   3    417
# 117      1       0  1009   3    341
# 47       0       1   939   3    345
# 172      0       1  1064   3    128
#
# [334 rows x 5 columns]

# %%
y_test
# Out:
#     Age
# 360   3
# 170   3
# 224   1
# 358   3
# 309   3
# ..   ..
# 100   1
# 7     2
# 22    1
# 68    1
# 328   2
#
# [84 rows x 1 columns]

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('test.csv')

# %%
df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df.shape
# Out:
# (418, 11)

# %%
df.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df.Age,df.Pclass)

# %%
x=df.iloc[:,0:1]
x
# Out:
#      PassengerId
# 0            892
# 1            893
# 2            894
# 3            895
# 4            896
# ..           ...
# 413         1305
# 414         1306
# 415         1307
# 416         1308
# 417         1309
#
# [418 rows x 1 columns]

# %%
y=df.iloc[:,1:]

# %%
y
# Out:
#      Pclass                                          Name     Sex   Age  \
# 0         3                              Kelly, Mr. James    male  34.5
# 1         3              Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 2         2                     Myles, Mr. Thomas Francis    male  62.0
# 3         3                              Wirz, Mr. Albert    male  27.0
# 4         3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0
# ..      ...                                           ...     ...   ...
# 413       3                            Spector, Mr. Woolf    male   NaN
# 414       1                  Oliva y Ocana, Dona. Fermina  female  39.0
# 415       3                  Saether, Mr. Simon Sivertsen    male  38.5
# 416       3                           Ware, Mr. Frederick    male   NaN
# 417       3                      Peter, Master. Michael J    male   NaN
#
#      SibSp  Parch              Ticket      Fare Cabin Embarked
# 0        0      0              330911    7.8292   NaN        Q
# 1        1      0              363272    7.0000   NaN        S
# 2        0      0              240276    9.6875   NaN        Q
# 3        0      0              315154    8.6625   NaN        S
# 4        1      1             3101298   12.2875   NaN        S
# ..     ...    ...                 ...       ...   ...      ...
# 413      0      0           A.5. 3236    8.0500   NaN        S
# 414      0      0            PC 17758  108.9000  C105        C
# 415      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416      0      0              359309    8.0500   NaN        S
# 417      1      1                2668   22.3583   NaN        C
#
# [418 rows x 10 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
print(x_train.shape) 
print(x_test.shape)
print(y_train.shape) 
print(y_test.shape)
# Out:
# (334, 1)
# (84, 1)
# (334, 10)
# (84, 10)

# %%
x_test
# Out:
#      PassengerId
# 360         1252
# 170         1062
# 224         1116
# 358         1250
# 309         1201
# ..           ...
# 100          992
# 7            899
# 22           914
# 68           960
# 328         1220
#
# [84 rows x 1 columns]

# %%
y_test
# Out:
#      Pclass                                               Name     Sex   Age  \
# 360       3                        Sage, Master. William Henry    male  14.5
# 170       3                                 Lithman, Mr. Simon    male   NaN
# 224       1   Candee, Mrs. Edward (Helen Churchill Hungerford)  female  53.0
# 358       3                               O'Keefe, Mr. Patrick    male   NaN
# 309       3         Hansen, Mrs. Claus Peter (Jennie L Howard)  female  45.0
# ..      ...                                                ...     ...   ...
# 100       1  Stengel, Mrs. Charles Emil Henry (Annie May Mo...  female  43.0
# 7         2                       Caldwell, Mr. Albert Francis    male  26.0
# 22        1               Flegenheim, Mrs. Alfred (Antoinette)  female   NaN
# 68        1                    Tucker, Mr. Gilbert Milligan Jr    male  31.0
# 328       2                      Clarke, Mr. Charles Valentine    male  29.0
#
#      SibSp  Parch         Ticket     Fare Cabin Embarked
# 360      8      2       CA. 2343  69.5500   NaN        S
# 170      0      0  S.O./P.P. 251   7.5500   NaN        S
# 224      0      0       PC 17606  27.4458   NaN        C
# 358      0      0         368402   7.7500   NaN        Q
# 309      1      0         350026  14.1083   NaN        S
# ..     ...    ...            ...      ...   ...      ...
# 100      1      0          11778  55.4417  C116        C
# 7        1      1         248738  29.0000   NaN        S
# 22       0      0       PC 17598  31.6833   NaN        S
# 68       0      0           2543  28.5375   C53        C
# 328      1      0           2003  26.0000   NaN        S
#
# [84 rows x 10 columns]

# %%
type(y)
# Out:
# pandas.core.frame.DataFrame

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
df.shape
# Out:
# (418, 11)

# %%
print(x_train.shape) 
print(x_test.shape)
print(y_train.shape) 
print(y_test.shape)
# Out:
# (334, 1)
# (84, 1)
# (334, 10)
# (84, 10)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_test,y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-c611d26c9680> in <module>
#       1 from sklearn.linear_model import LinearRegression
#       2 lr = LinearRegression()
# ----> 3 lr.fit(x_test,y_test)
#
# NameError: name 'x_test' is not defined

# %%
x_test
# Out:
#      PassengerId
# 360         1252
# 170         1062
# 224         1116
# 358         1250
# 309         1201
# ..           ...
# 100          992
# 7            899
# 22           914
# 68           960
# 328         1220
#
# [84 rows x 1 columns]

# %%
y_train
# Out:
#      Pclass                                               Name     Sex   Age  \
# 20        1                             Rothschild, Mr. Martin    male  55.0
# 306       1               Allison, Mr. Hudson Joshua Creighton    male  30.0
# 142       1                         Ryerson, Mr. Arthur Larned    male  61.0
# 14        1  Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0
# 284       3                        Rosblom, Miss. Salli Helena  female   2.0
# ..      ...                                                ...     ...   ...
# 323       1                                 Rowe, Mr. Alfred G    male  33.0
# 192       3                  van Billiard, Master. Walter John    male  11.5
# 117       3                    Sandstrom, Miss. Beatrice Irene  female   1.0
# 47        3                           Shaughnessy, Mr. Patrick    male   NaN
# 172       3                           Dyker, Mr. Adolf Fredrik    male  23.0
#
#      SibSp  Parch       Ticket      Fare            Cabin Embarked
# 20       1      0     PC 17603   59.4000              NaN        C
# 306      1      2       113781  151.5500          C22 C26        S
# 142      1      3     PC 17608  262.3750  B57 B59 B63 B66        C
# 14       1      0  W.E.P. 5734   61.1750              E31        S
# 284      1      1       370129   20.2125              NaN        S
# ..     ...    ...          ...       ...              ...      ...
# 323      0      0       113790   26.5500              NaN        S
# 192      1      1     A/5. 851   14.5000              NaN        S
# 117      1      1      PP 9549   16.7000               G6        S
# 47       0      0       370374    7.7500              NaN        Q
# 172      1      0       347072   13.9000              NaN        S
#
# [334 rows x 10 columns]

# %%
x_train
# Out:
#      PassengerId
# 20           912
# 306         1198
# 142         1034
# 14           906
# 284         1176
# ..           ...
# 323         1215
# 192         1084
# 117         1009
# 47           939
# 172         1064
#
# [334 rows x 1 columns]

# %%
y_test
# Out:
#      Pclass                                               Name     Sex   Age  \
# 360       3                        Sage, Master. William Henry    male  14.5
# 170       3                                 Lithman, Mr. Simon    male   NaN
# 224       1   Candee, Mrs. Edward (Helen Churchill Hungerford)  female  53.0
# 358       3                               O'Keefe, Mr. Patrick    male   NaN
# 309       3         Hansen, Mrs. Claus Peter (Jennie L Howard)  female  45.0
# ..      ...                                                ...     ...   ...
# 100       1  Stengel, Mrs. Charles Emil Henry (Annie May Mo...  female  43.0
# 7         2                       Caldwell, Mr. Albert Francis    male  26.0
# 22        1               Flegenheim, Mrs. Alfred (Antoinette)  female   NaN
# 68        1                    Tucker, Mr. Gilbert Milligan Jr    male  31.0
# 328       2                      Clarke, Mr. Charles Valentine    male  29.0
#
#      SibSp  Parch         Ticket     Fare Cabin Embarked
# 360      8      2       CA. 2343  69.5500   NaN        S
# 170      0      0  S.O./P.P. 251   7.5500   NaN        S
# 224      0      0       PC 17606  27.4458   NaN        C
# 358      0      0         368402   7.7500   NaN        Q
# 309      1      0         350026  14.1083   NaN        S
# ..     ...    ...            ...      ...   ...      ...
# 100      1      0          11778  55.4417  C116        C
# 7        1      1         248738  29.0000   NaN        S
# 22       0      0       PC 17598  31.6833   NaN        S
# 68       0      0           2543  28.5375   C53        C
# 328      1      0           2003  26.0000   NaN        S
#
# [84 rows x 10 columns]

# %%
lr.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-a7869d97f82d> in <module>
# ----> 1 lr.predict(x_test)
#
# NameError: name 'x_test' is not defined

# %%
import seaborn as sns
sns.heatmap(df.corr(),annot=True)

# %% [raw]
# Simple Linear Regression
# import pandas as pd
# import numpy as np
# df=pd.read_csv('Salary_Data.csv')
# df.head()
# YearsExperience	Salary
# 0	1.1	39343.0
# 1	1.3	46205.0
# 2	1.5	37731.0
# 3	2.0	43525.0
# 4	2.2	39891.0
# df.shape
# (30, 2)
# df.describe()
# YearsExperience	Salary
# count	30.000000	30.000000
# mean	5.313333	76003.000000
# std	2.837888	27414.429785
# min	1.100000	37731.000000
# 25%	3.200000	56720.750000
# 50%	4.700000	65237.000000
# 75%	7.700000	100544.750000
# max	10.500000	122391.000000
# df.info()
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 608.0 bytes
# df.isnull().sum()
# YearsExperience    0
# Salary             0
# dtype: int64
# df.columns
# Index(['YearsExperience', 'Salary'], dtype='object')
# import matplotlib.pyplot as plt
# plt.scatter(df.YearsExperience,df.Salary)
# <matplotlib.collections.PathCollection at 0x213e80c7d30>
#
# Independent & Dependent Variable
# #independent variable
# x=df.iloc[:,0:1]
# x
# YearsExperience
# 0	1.1
# 1	1.3
# 2	1.5
# 3	2.0
# 4	2.2
# 5	2.9
# 6	3.0
# 7	3.2
# 8	3.2
# 9	3.7
# 10	3.9
# 11	4.0
# 12	4.0
# 13	4.1
# 14	4.5
# 15	4.9
# 16	5.1
# 17	5.3
# 18	5.9
# 19	6.0
# 20	6.8
# 21	7.1
# 22	7.9
# 23	8.2
# 24	8.7
# 25	9.0
# 26	9.5
# 27	9.6
# 28	10.3
# 29	10.5
# #Dependent Variable
# y=df.iloc[:,1:]
# y
# Salary
# 0	39343.0
# 1	46205.0
# 2	37731.0
# 3	43525.0
# 4	39891.0
# 5	56642.0
# 6	60150.0
# 7	54445.0
# 8	64445.0
# 9	57189.0
# 10	63218.0
# 11	55794.0
# 12	56957.0
# 13	57081.0
# 14	61111.0
# 15	67938.0
# 16	66029.0
# 17	83088.0
# 18	81363.0
# 19	93940.0
# 20	91738.0
# 21	98273.0
# 22	101302.0
# 23	113812.0
# 24	109431.0
# 25	105582.0
# 26	116969.0
# 27	112635.0
# 28	122391.0
# 29	121872.0
# type(y)
# pandas.core.frame.DataFrame
# df.shape
# (30, 2)
# Train,Test & Split
# from sklearn.model_selection import train_test_split
# x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)
# ​
# print(x_train.shape) #training input
# print(x_test.shape)#testing input
# print(y_train.shape) #training output
# print(y_test.shape)#testing output
# (24, 1)
# (6, 1)
# (24, 1)
# (6, 1)
# Model Building
# from sklearn.linear_model import LinearRegression
# lr=LinearRegression()
# lr.fit(x_train,y_train)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c1d813126ab8> in <module>
#       1 from sklearn.linear_model import LinearRegression
#       2 lr=LinearRegression()
# ----> 3 lr.fit(x_train,y_train)
#
# NameError: name 'x_train' is not defined
#
# x_test
# YearsExperience
# 2	1.5
# 28	10.3
# 13	4.1
# 10	3.9
# 26	9.5
# 24	8.7
# y_test
# Salary
# 2	37731.0
# 28	122391.0
# 13	57081.0
# 10	63218.0
# 26	116969.0
# 24	109431.0
# lr.predict(x_test)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-a7869d97f82d> in <module>
# ----> 1 lr.predict(x_test)
#
# NameError: name 'x_test' is not defined
#
# from sklearn.metrics import r2_score
# r2_score(lr.predict(x_test),y_test)
# 0.986482673117654
# df
# YearsExperience	Salary
# 0	1.1	39343.0
# 1	1.3	46205.0
# 2	1.5	37731.0
# 3	2.0	43525.0
# 4	2.2	39891.0
# 5	2.9	56642.0
# 6	3.0	60150.0
# 7	3.2	54445.0
# 8	3.2	64445.0
# 9	3.7	57189.0
# 10	3.9	63218.0
# 11	4.0	55794.0
# 12	4.0	56957.0
# 13	4.1	57081.0
# 14	4.5	61111.0
# 15	4.9	67938.0
# 16	5.1	66029.0
# 17	5.3	83088.0
# 18	5.9	81363.0
# 19	6.0	93940.0
# 20	6.8	91738.0
# 21	7.1	98273.0
# 22	7.9	101302.0
# 23	8.2	113812.0
# 24	8.7	109431.0
# 25	9.0	105582.0
# 26	9.5	116969.0
# 27	9.6	112635.0
# 28	10.3	122391.0
# 29	10.5	121872.0
# salary=lr.predict([[7.5]])
# print('Salary will be :',salary)
# Salary will be : [[96624.4126011]]
# import seaborn as sns
# sns.heatmap(df.corr(),annot=True)
# <AxesSubplot:>
#
# plt.scatter(x_train,y_train)
# plt.plot(x_train,lr.predict(x_train),'r')
# [<matplotlib.lines.Line2D at 0x213eac7b070>]
#
# Multiple Linear Regression
# df=pd.read_csv('50_Startups.csv')
# df.head()
# R&D Spend	Administration	Marketing Spend	State	Profit
# 0	165349.20	136897.80	471784.10	New York	192261.83
# 1	162597.70	151377.59	443898.53	California	191792.06
# 2	153441.51	101145.55	407934.54	Florida	191050.39
# 3	144372.41	118671.85	383199.62	New York	182901.99
# 4	142107.34	91391.77	366168.42	Florida	166187.94
# df.shape
# (108, 5)
# df.describe()
# R&D Spend	Administration	Marketing Spend	Profit
# count	108.000000	108.000000	108.000000	108.000000
# mean	74959.338704	121750.788889	214952.664722	113523.760000
# std	44996.368152	27322.385654	117937.942120	38991.013654
# min	0.000000	51283.140000	0.000000	14681.400000
# 25%	38558.510000	105077.645000	134050.070000	90708.190000
# 50%	75791.365000	122699.795000	239452.750000	109543.120000
# 75%	101913.080000	145077.580000	298664.470000	141585.520000
# max	165349.200000	182645.560000	471784.100000	192261.830000
# df.info()
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108 entries, 0 to 107
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        108 non-null    float64
#  1   Administration   108 non-null    float64
#  2   Marketing Spend  108 non-null    float64
#  3   State            108 non-null    object
#  4   Profit           108 non-null    float64
# dtypes: float64(4), object(1)
# memory usage: 4.3+ KB
# df.isnull().sum()
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64
# Label Encoding
# ​
# New York      39
# California    36
# Florida       33
# Name: State, dtype: int64
# df.State=le.fit_transform(df.State)
# print(df.State.value_counts())
# 2    39
# 0    36
# 1    33
# Name: State, dtype: int64
# df.head()
# R&D Spend	Administration	Marketing Spend	State	Profit
# 0	165349.20	136897.80	471784.10	2	192261.83
# 1	162597.70	151377.59	443898.53	0	191792.06
# 2	153441.51	101145.55	407934.54	1	191050.39
# 3	144372.41	118671.85	383199.62	2	182901.99
# 4	142107.34	91391.77	366168.42	1	166187.94
# df.info()
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108 entries, 0 to 107
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        108 non-null    float64
#  1   Administration   108 non-null    float64
#  2   Marketing Spend  108 non-null    float64
#  3   State            108 non-null    int32
#  4   Profit           108 non-null    float64
# dtypes: float64(4), int32(1)
# memory usage: 3.9 KB
# Independent & Dependent
# #independent variable
# x=df.iloc[:,:4]
# x.head()
# R&D Spend	Administration	Marketing Spend	State
# 0	165349.20	136897.80	471784.10	2
# 1	162597.70	151377.59	443898.53	0
# 2	153441.51	101145.55	407934.54	1
# 3	144372.41	118671.85	383199.62	2
# 4	142107.34	91391.77	366168.42	1
# #dependent variable
# y=df.iloc[:,4:]
# y.head()
# Profit
# 0	192261.83
# 1	191792.06
# 2	191050.39
# 3	182901.99
# 4	166187.94
# Train,Test & Split
# from sklearn.model_selection import train_test_split
# x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)
# ​
# df.shape
# (108, 5)
# print(x_train.shape) #training input
# print(x_test.shape) #testing input
# print(y_train.shape) #training output
# print(y_test.shape) #testing output
# (86, 4)
# (22, 4)
# (86, 1)
# (22, 1)
# Model Building
# from sklearn.linear_model import LinearRegression
# mlr=LinearRegression()
# mlr.fit(x_train,y_train)
# LinearRegression()
# y_test[0:5]
# Profit
# 84	64926.08
# 10	146121.95
# 75	90708.19
# 2	191050.39
# 24	108552.04
# x_test[0:5]
# R&D Spend	Administration	Marketing Spend	State
# 84	1000.23	124153.04	1903.93	2
# 10	101913.08	110594.11	229160.95	1
# 75	28663.76	127056.21	201126.82	1
# 2	153441.51	101145.55	407934.54	1
# 24	77044.01	99281.34	140574.81	2
# mlr.predict(x_test)
# array([[ 48379.24868384],
#        [134848.91924675],
#        [ 76483.10965219],
#        [181561.78529195],
#        [112966.00035119],
#        [134241.68257234],
#        [129222.38731943],
#        [160017.05919782],
#        [116752.96050773],
#        [ 46260.99264065],
#        [102266.36060186],
#        [115568.27177595],
#        [ 48379.24868384],
#        [119114.16525517],
#        [ 88602.220028  ],
#        [127101.40273621],
#        [127101.40273621],
#        [ 90942.33421504],
#        [ 58677.73349899],
#        [146304.26215169],
#        [149410.05440997],
#        [152502.87810445]])
# predict=mlr.predict(x_test)
# predict[0:5]
# array([[ 48379.24868384],
#        [134848.91924675],
#        [ 76483.10965219],
#        [181561.78529195],
#        [112966.00035119]])
# from sklearn.metrics import r2_score
# r2_score(mlr.predict(x_test),y_test)
# 0.9314720388994492
# x_test.head()
# R&D Spend	Administration	Marketing Spend	State
# 84	1000.23	124153.04	1903.93	2
# 10	101913.08	110594.11	229160.95	1
# 75	28663.76	127056.21	201126.82	1
# 2	153441.51	101145.55	407934.54	1
# 24	77044.01	99281.34	140574.81	2
# mlr.predict([[238663.76,537056.21,801126.82,0]])
# array([[256890.95063612]])
# r2_score(mlr.predict(x_train),y_train)
# 0.9335574224154842
# Polynomial Regression
# df=pd.read_csv('Position_Salaries.csv')
# df.head()
# Position	Level	Salary
# 0	Business Analyst	1	45000
# 1	Junior Consultant	2	50000
# 2	Senior Consultant	3	60000
# 3	Manager	4	80000
# 4	Country Manager	5	110000
# df
# Position	Level	Salary
# 0	Business Analyst	1	45000
# 1	Junior Consultant	2	50000
# 2	Senior Consultant	3	60000
# 3	Manager	4	80000
# 4	Country Manager	5	110000
# 5	Region Manager	6	150000
# 6	Partner	7	200000
# 7	Senior Partner	8	300000
# 8	C-level	9	500000
# 9	CEO	10	1000000
# df.corr()
# Level	Salary
# Level	1.000000	0.817949
# Salary	0.817949	1.000000
# x=df.iloc[:,1:2]
# x.head()
# Level
# 0	1
# 1	2
# 2	3
# 3	4
# 4	5
# y=df.iloc[:,2:]
# y.head()
# Salary
# 0	45000
# 1	50000
# 2	60000
# 3	80000
# 4	110000
# plt.scatter(x,y)
# <matplotlib.collections.PathCollection at 0x213eae137c0>
#
# from sklearn.preprocessing import PolynomialFeatures
# pr=PolynomialFeatures(degree=4)
# xp=pr.fit_transform(x)
# xp
# array([[1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00],
#        [1.000e+00, 2.000e+00, 4.000e+00, 8.000e+00, 1.600e+01],
#        [1.000e+00, 3.000e+00, 9.000e+00, 2.700e+01, 8.100e+01],
#        [1.000e+00, 4.000e+00, 1.600e+01, 6.400e+01, 2.560e+02],
#        [1.000e+00, 5.000e+00, 2.500e+01, 1.250e+02, 6.250e+02],
#        [1.000e+00, 6.000e+00, 3.600e+01, 2.160e+02, 1.296e+03],
#        [1.000e+00, 7.000e+00, 4.900e+01, 3.430e+02, 2.401e+03],
#        [1.000e+00, 8.000e+00, 6.400e+01, 5.120e+02, 4.096e+03],
#        [1.000e+00, 9.000e+00, 8.100e+01, 7.290e+02, 6.561e+03],
#        [1.000e+00, 1.000e+01, 1.000e+02, 1.000e+03, 1.000e+04]])
# lr1=LinearRegression()
# lr1.fit(x,y)
# LinearRegression()
# plt.scatter(x,y)
# plt.plot(x,lr1.predict(x),'r')
# plt.title('Linear Regression')
# plt.xlabel('Levels')
# plt.ylabel('Salary')
# Text(0, 0.5, 'Salary')
#
# lr2=LinearRegression()
# lr2.fit(xp,y)
# LinearRegression()
# from sklearn.preprocessing import PolynomialFeatures
# pr=PolynomialFeatures(degree=6)
# xp=pr.fit_transform(x)
# lr2=LinearRegression()
# lr2.fit(xp,y)
# LinearRegression()
# plt.scatter(x,y)
# plt.plot(x,lr2.predict(pr.fit_transform(x)),'r')
# plt.title('Polynomial Linear Regression')
# plt.xlabel('Levels')
# plt.ylabel('Salary')
# Text(0, 0.5, 'Salary')
#
# salary=lr1.predict([[6.5]])
# print('Salary Will be :',salary)
# Salary Will be : [[330378.78787879]]
# df
# Position	Level	Salary
# 0	Business Analyst	1	45000
# 1	Junior Consultant	2	50000
# 2	Senior Consultant	3	60000
# 3	Manager	4	80000
# 4	Country Manager	5	110000
# 5	Region Manager	6	150000
# 6	Partner	7	200000
# 7	Senior Partner	8	300000
# 8	C-level	9	500000
# 9	CEO	10	1000000
# salary=lr2.predict(pr.fit_transform([[9.5]]))
# print('Salary Will be :',salary)
# Salary Will be : [[697643.17851882]]
